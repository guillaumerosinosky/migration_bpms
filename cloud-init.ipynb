# %%
import subprocess
import shlex

def run_command(command):
    print("Launch " + command)
    process = subprocess.Popen(shlex.split(command), stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
    while True:
        output = process.stdout.readline().decode()
        if output == '' and process.poll() is not None:
            break
        if output:
            print (output.strip())
    rc = process.poll()
    return rc
import os

class cd:
    """Context manager for changing the current working directory"""
    def __init__(self, newPath):
        self.newPath = os.path.expanduser(newPath)

    def __enter__(self):
        self.savedPath = os.getcwd()
        os.chdir(self.newPath)

    def __exit__(self, etype, value, traceback):
        os.chdir(self.savedPath)

# %%
# initialize infra
command = './create_vm.sh migration_azure_vm_vnet1_5'
res = run_command(command)
# Out:
# Launch ./create_vm.sh migration_azure_vm_vnet1_5
# [DEPRECATION WARNING]: 'include' for playbook includes. You should use
# 'import_playbook' instead. This feature will be removed in version 2.8.
# Deprecation warnings can be disabled by setting deprecation_warnings=False in
# ansible.cfg.
#
# PLAY [localhost] ***************************************************************
#
# TASK [Validate 'bcd_stack_id' variable.] ***************************************
# skipping: [localhost]
#
# PLAY [localhost] ***************************************************************
#
# TASK [infra_azure : include] ***************************************************
# included: /home/ubuntu/git/bonita-provisioning/ansible/roles/infra_azure/tasks/create_fdw_swarm.yml for localhost
#
# TASK [infra_azure : Create a resource group] ***********************************
# changed: [localhost]
#
# TASK [infra_azure : Create public IP address] **********************************
# changed: [localhost]
#
# ...

# %%
run_command('ssh-keygen -f "/home/ubuntu/.ssh/known_hosts" -R vm-vmonly-bpm-agent1')
run_command('ssh-keygen -f "/home/ubuntu/.ssh/known_hosts" -R vm-vmonly-bpm-agent2')
run_command('ssh-keygen -f "/home/ubuntu/.ssh/known_hosts" -R vm-vmonly-bpm-agent3')
run_command('ssh-keygen -f "/home/ubuntu/.ssh/known_hosts" -R vm-vmonly-bpm-agent4')
run_command('ssh-keygen -f "/home/ubuntu/.ssh/known_hosts" -R vm-vmonly-bpm-agent5')
# Out:
# Launch ssh-keygen -f "/home/ubuntu/.ssh/known_hosts" -R vm-vmonly-bpm-agent1
# # Host vm-vmonly-bpm-agent1 found: line 97
# /home/ubuntu/.ssh/known_hosts updated.
# Original contents retained as /home/ubuntu/.ssh/known_hosts.old
# Launch ssh-keygen -f "/home/ubuntu/.ssh/known_hosts" -R vm-vmonly-bpm-agent2
# # Host vm-vmonly-bpm-agent2 found: line 77
# /home/ubuntu/.ssh/known_hosts updated.
# Original contents retained as /home/ubuntu/.ssh/known_hosts.old
# Launch ssh-keygen -f "/home/ubuntu/.ssh/known_hosts" -R vm-vmonly-bpm-agent3
# # Host vm-vmonly-bpm-agent3 found: line 77
# /home/ubuntu/.ssh/known_hosts updated.
# Original contents retained as /home/ubuntu/.ssh/known_hosts.old
# Launch ssh-keygen -f "/home/ubuntu/.ssh/known_hosts" -R vm-vmonly-bpm-agent4
# # Host vm-vmonly-bpm-agent4 found: line 77
# /home/ubuntu/.ssh/known_hosts updated.
# Original contents retained as /home/ubuntu/.ssh/known_hosts.old
# ...
